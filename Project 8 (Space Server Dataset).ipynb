# %% [markdown]
# <h1>Project 8</h1>

# %% [markdown]
# <h2>Space Server Dataset</h2>

# %% [markdown]
# <img src="https://cdn.pixabay.com/photo/2016/03/29/08/48/project-1287781_1280.jpg">

# %% [markdown]
# ***First importing necessary packages***

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***Importing data which is in csv format***

# %%
df=pd.read_csv('Space_Server_Dataset.csv')
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %% [markdown]
# <h2>Start of EDA process</h2>

# %% [markdown]
# ***Checking data types and null count of the columns***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %% [markdown]
# ***Checking shape of the Dataset***

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# **Observation** : There is no null or NAN value in the table

# %% [markdown]
# ***Checking unique elements in type with visualization***

# %%
print(sns.countplot(df['class']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# The feature's value seems to be out of range for certain type of plots such as histogram

# %% [markdown]
# Since all the features are important in cassifying it as either star or galaxy class or QSO, we will not drop any features

# %%
col=['objid','ra','dec','u','g','r','i','z','run','rerun','camcol','field','specobjid','redshift','plate','mjd','fiberid']
     
for i in range(0,17):
    print(sns.violinplot(x="class", y=df[col[i]], data=df))
    plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
for i in range(0,17):
    print(sns.boxplot(df[col[i]],color='g'))
    plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# We can see visually that there are multiple dots outside the plot which are indicating outliers, here its huge

# %% [markdown]
# ***lets convert region also to interger values, so it will be easier for us to do further process***

# %% [markdown]
# ***Converting categorical in to numerical using label encoder***

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['class'])
cls =le.transform(df['class'])
df=df.drop(['class'],axis=1)
clas=pd.DataFrame(cls)
df['class']=clas
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid  redshift  plate    mjd  \
# 0  15.22531  752    301       4    267  3.722360e+18 -0.000009   3306  54922
# 1  16.39150  752    301       4    267  3.638140e+17 -0.000055    323  51615
# 2  16.80125  752    301       4    268  3.232740e+17  0.123111    287  52023
# 3  15.90438  752    301       4    269  3.722370e+18 -0.000111   3306  54922
# 4  16.61326  752    301       4    269  3.722370e+18  0.000590   3306  54922
#
#    fiberid  class
# ...

# %% [markdown]
# ***Lets calculate correlation***

# %%
df.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %% [markdown]
# ***Lets visualize using heat map as well***

# %%
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(12, 12))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True,annot=True, linewidths=0.5,cmap="YlGnBu")

# %%
x=df[['objid','ra','dec','u','g','r','i','z','run','rerun','camcol','field','specobjid','redshift','plate','mjd','fiberid']]
x.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid  redshift  plate    mjd  \
# 0  15.22531  752    301       4    267  3.722360e+18 -0.000009   3306  54922
# 1  16.39150  752    301       4    267  3.638140e+17 -0.000055    323  51615
# 2  16.80125  752    301       4    268  3.232740e+17  0.123111    287  52023
# 3  15.90438  752    301       4    269  3.722370e+18 -0.000111   3306  54922
# 4  16.61326  752    301       4    269  3.722370e+18  0.000590   3306  54922
#
#    fiberid
# 0      491
# ...

# %%
y=df[['class']]
y.head()
# Out:
#    class
# 0      2
# 1      2
# 2      0
# 3      2
# 4      2

# %% [markdown]
# **Note**: Outliers and skew test was not done as most of the attributes out of range to handle precisely

# %% [markdown]
# We have both of input and output attributes cleaned and in desired format

# %% [markdown]
# <h2>End of EDA Process</h2>

# %% [markdown]
# Lets start Building models to make predictions and find the model that works best on our dataset

# %% [markdown]
# <h2>Start of Machine Learning Process</h2>

# %% [markdown]
# Since out target variable is multivariant, we are going to do classification analysis

# %% [markdown]
# ***Lets import required packages***

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
SV=SVC()
LR=LogisticRegression()
DT=DecisionTreeClassifier(random_state=6)

# %%
models = []
models.append(('KNeighborsClassifier', KNN))
models.append(('SVC', SV))
models.append(('LogisticRegression', LR))
models.append(('DecisionTreeClassifier', DT))

# %% [markdown]
# ***Lets create a loop that will execute all our models***

# %%
Model = []
score = []
cvs=[]
for name,model in models:
    print('*-----------------------------*',name,'*------------------------------*')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score = ',AS*100)
    score.append(AS*100)
    print('\n')
    sc = cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score = ',sc*100)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n\n')
# Out:
# *-----------------------------* KNeighborsClassifier *------------------------------*
#
#
# KNeighborsClassifier(n_neighbors=6)
#
#
# Accuracy_score =  78.43333333333334
#
#
# Cross_Val_Score =  76.24000000000001
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83      1497
#            1       0.39      0.05      0.09       286
#            2       0.89      0.76      0.82      1217
#
#     accuracy                           0.78      3000
#    macro avg       0.67      0.58      0.58      3000
# weighted avg       0.76      0.78      0.75      3000
#
#
#
#
# *-----------------------------* SVC *------------------------------*
#
#
# SVC()
#
#
# Accuracy_score =  78.76666666666667
#
#
# Cross_Val_Score =  79.68
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.73      0.98      0.83      1497
# ...

# %%
result = pd.DataFrame({'Classification Model': Model, 'Accuracy score': score ,'Cross Validation Score':cvs})
result
# Out:
#      Classification Model  Accuracy score  Cross Validation Score
# 0    KNeighborsClassifier       78.433333                   76.24
# 1                     SVC       78.766667                   79.68
# 2      LogisticRegression       49.900000                   49.98
# 3  DecisionTreeClassifier       98.433333                   98.32

# %% [markdown]
# *MultinomialNB is not inculded because it is taking data with negative values*

# %% [markdown]
# **DecisionTreeClassifier works best with highest accuracy and cross validation score is also high**

# %% [markdown]
# <h2>End of Machine learning Process</h2>

# %% [markdown]
# <h1>Now lets save our final model</h1>

# %%
import joblib
joblib.dump(DT,'Space_Server_Dataset.pkl')
# Out:
# ['Space_Server_Dataset.pkl']

# %% [markdown]
# <img src="https://knowledge.wharton.upenn.edu/wp-content/uploads/2020/05/Women-in-data-science.jpg">
